# %% [markdown]
# 1.      Загрузить датасет, подготовить датасет, выполнить исследование и отбор признаков. Обучить два Байесовских классификатора. Выполнить прогноз на проверочных данных.
# Датасет: 10_fire_dataset_bin.xlsx
# данные о лесных пожарах.
# Целевая переменная - area

# %%
import pandas as pd
from zipfile import ZipFile

# %%
with pd.ExcelFile(ZipFile("../data/10_fire_dataset_bin.zip", 'r').open("10_fire_dataset_bin.xlsx")) as xl_file:
    df = pd.read_excel(io=xl_file, sheet_name="fire_dataset_bin", index_col=0)

# %%
df.describe()
# Out:
#               area          lon          lat       Dist_str    Dist_railw  \
# count  8166.000000  8166.000000  8166.000000    8166.000000   8166.000000
# mean      0.051678     2.611662     2.745962    1902.796763    869.270501
# std       0.221389    11.190458    11.764578   10783.521134   4721.993706
# min       0.000000     0.000000     0.000000       0.000000      0.000000
# 25%       0.000000     0.000000     0.000000       0.000000      0.000000
# 50%       0.000000     0.000000     0.000000       0.000000      0.000000
# 75%       0.000000     0.000000     0.000000       0.000000      0.000000
# max       1.000000    52.419154    54.624496  139339.388668  53919.346006
#
#           Dist_car            T           Po            P           Pa  \
# count  8166.000000  8166.000000  8166.000000  8166.000000  8166.000000
# mean     30.162300     5.469949   750.730541   763.665711     0.011254
# std     178.232637    11.845542     7.528750     7.882456     0.974373
# ...
