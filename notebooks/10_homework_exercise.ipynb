# %% [markdown]
# 1.      Загрузить датасет, подготовить датасет, выполнить исследование и отбор признаков. Обучить алгоритм линейной регрессии для прогнозирования значений. Выполнить прогноз на проверочных данных. Выполнить прогноз на проверочных данных. Снять метрики и ошибки модели. Написать выводы.
# Датасет: 14_Real estate valuation data set.xlsx
# Определение стоимости недвижимости целевая переменная – Y
#
# 2.      Загрузить датасет, подготовить датасет, выполнить исследование и отбор признаков. Обучить алгоритм логистической регрессии для классификации значений. Выполнить прогноз на проверочных данных. Выполнить прогноз на проверочных данных. Снять метрики и ошибки модели. Написать выводы.
# Датасет: 13_credit_approve.rar
# Датасет содержит данные об одобрении или отказе в выдаче кредита клиентам.
# целевая переменная А16 - “+\-”
